# %% [markdown]
# # Must watch ER Diagrams from IITM Lectures

# %% [markdown]
# Great! Let’s **learn this step-by-step** like a teacher explaining in class — starting from the very basics.
#
# ---
#
# ## 🧠 LESSON: **Relations and ER Diagrams**
#
# ---
#
# ### 🔹 **1. Structured vs Unstructured Databases**
#
# #### 🔸 What is a **Structured Database**?
#
# * Data is stored in a **fixed format** — like tables (rows and columns).
# * Easy to **search**, **filter**, and **update**.
# * Uses languages like **SQL** to interact with the database.
#
# #### ✅ Example:
#
# Imagine a table storing student data:
#
# | ID | Name | Age |
# | -- | ---- | --- |
# | 1  | Raj  | 18  |
# | 2  | Neha | 19  |
#
# This is structured — every row and column has a clear meaning.
#
# ---
#
# #### 🔸 What is an **Unstructured Database**?
#
# * No fixed format — data could be images, emails, PDFs, videos.
# * Harder to search and manage.
# * Uses NoSQL databases like MongoDB, or cloud storage.
#
# #### ✅ Example:
#
# A folder with:
#
# * `photo.jpg`
# * `resume.pdf`
# * `voice_note.mp3`
#
# That’s unstructured — you can't query it with SQL directly.
#
# ---
#
# ### 🔹 **2. Adding, Updating, Deleting Data in Structured Databases**
#
# In **SQL**, you use basic commands:
#
# | Task   | SQL Command                                   | Meaning                           |
# | ------ | --------------------------------------------- | --------------------------------- |
# | Add    | `INSERT INTO students VALUES (1, 'Raj');`     | Adds a new student                |
# | Update | `UPDATE students SET name='Neha' WHERE id=1;` | Changes name of student with ID 1 |
# | Delete | `DELETE FROM students WHERE id=1;`            | Deletes the student with ID 1     |
#
# ---
#
# ### 🔹 **3. What is a Relationship in a Database?**
#
# When **tables are connected**, we call it a **relationship**.
#
# #### 🎓 Example:
#
# You have two tables:
#
# **Student Table**
#
# | ID | Name |
# | -- | ---- |
# | 1  | Raj  |
#
# **Course Table**
#
# | CourseID | StudentID | CourseName |
# | -------- | --------- | ---------- |
# | 101      | 1         | Math       |
#
# 🧩 Here: `StudentID` connects to `ID` → **Relationship** formed between **Student and Course**.
#
# ---
#
# ### 🔹 **4. Types of Relationships in ER Diagrams**
#
# #### 🧾 ER Diagram: Entity-Relationship Diagram
#
# It’s a **picture** that shows:
#
# * **Entities** (tables)
# * **Attributes** (columns)
# * **Relationships** (connections)
#
# #### 🔗 Relationship Types:
#
# 1. **One-to-One**
#
#    * One entity connects to only one other.
#    * Example: 1 student ↔ 1 Aadhaar card.
#
# 2. **One-to-Many**
#
#    * One entity connects to **many** of another.
#    * Example: 1 teacher ↔ many students.
#
# 3. **Many-to-Many**
#
#    * Many entities relate to many others.
#    * Example: Students ↔ Courses (many students take many courses).
#
# ---
#
# ### 🔚 Summary:
#
# | Concept             | Meaning                                  |
# | ------------------- | ---------------------------------------- |
# | **Structured DB**   | Organized in tables, queryable with SQL  |
# | **Unstructured DB** | Raw files like images, text, videos      |
# | **CRUD**            | Create, Read, Update, Delete data in DB  |
# | **Relationships**   | Links between tables using keys          |
# | **ER Diagram**      | Visual tool to design database structure |
#
# ---
