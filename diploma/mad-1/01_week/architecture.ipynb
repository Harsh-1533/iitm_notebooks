# %% [markdown]
# # **Architectures**
#
# ### *1. Client-Server*
# ### *2. Distributed - peer-to-peer*
#
# ### **1. Client Server Model**
# - Explicit differentiation between clients and servers
# - Local systems:
#     - both client and server on same machine - local network / communication
#     - conceptually still a networked system
# - Machine clients
#     - eg. Software / antivirus updaters
#     - Need not have user interaction
# - Variants
#     - Multiple servers, single queue, multiple queues, load balancing frontends
# - Examples:
#     - Email
#     - Databases
#     - WhatsApp/messaging
#     - Web browsing
# ### **2. Distributed (Peer-to-Peer) Model**
# - All peers are considered "equivalent"
#     - But some peers may be more equal than others...
# - Error tolerance
#     - Masters / introducers
#     - Election/re-selection of masters on failure
# - Shared information
# - Examples:
#     - Bittorrent
#     - Blockchain-based systems
#     - IPFS, Tahoe (distributed file systems)

# %% [markdown]
# # **By ChatGPT**
#
# ## 🔵 **1. Client-Server Architecture**
#
# #### 🔹 Definition:
# - In Client-Server Architecture, there is:
#    - A server (central computer) that provides services or data.
#    - One or more clients (user computers or devices) that request and use those services.
#
# #### 🔹 How it works:
#    - The client sends a request to the server.
#    - The server processes it and sends back the response.
#
# #### 🔹 Examples:
#    - Gmail (your phone or browser is the client, Google’s server handles email)
#    - Websites (browser = client, web server = server)
#
# #### 🔹 Features:
#    - Centralized control
#    - Easy to manage and secure
#    - Server can become a bottleneck (if overloaded)
#
# ## 🔵 **2. Peer-to-Peer (P2P) Architecture**
#
# #### 🔹 Definition:
# - In Peer-to-Peer Architecture, each device (peer) acts as both a client and a server. There is no central server.
#
# #### 🔹 How it works:
#    - Each peer can request and provide services to other peers.
#    - All peers are equal in terms of functionality.
#
# #### 🔹 Examples:
#    - File sharing apps like BitTorrent
#    - Some multiplayer games
#
# #### 🔹 Features:
#    - Decentralized system
#    - More scalable (adding peers increases power)
#    - Harder to manage and secure

# %% [markdown]
# | Feature          | Client-Server                   | Peer-to-Peer (P2P)                |
# | ---------------- | ------------------------------- | --------------------------------- |
# | Control          | Centralized                     | Decentralized                     |
# | Data Location    | Stored on server                | Shared among peers                |
# | Scalability      | Limited by server capacity      | Scales with more peers            |
# | Example          | Gmail, Facebook                 | BitTorrent, Blockchain            |
# | Setup Complexity | Easy to manage centrally        | Harder to manage                  |
# | Fault Tolerance  | Low (if server fails, all fail) | High (no single point of failure) |
#
# ✅ Quick Summary
# Client-Server: One server, many clients. Centralized control.
#
# Peer-to-Peer: All devices are equal. Share resources directly.
