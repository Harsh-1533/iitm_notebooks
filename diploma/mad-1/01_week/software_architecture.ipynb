# %% [markdown]
# # **Software Architectures**
#
# ### What is a design pattern?
#
# - "A general, reusable solution to a commonly occurring problem within a given context in software design." -- Src: Wikipedia
#
# ---
#
# - Experienced designers observe "patterns" in code
# - Reusing these patterns can make design and development faster
# - Guide the design and thought process

# %% [markdown]
# ## **M-V-C paradigm**
#
# #### Model:
#
# - Core data to be stored for the application
# - Databases; indexing for easy searching, manipulation;
#
# #### View:
#
# - User-facing side of application
# - Interfaces for finding information, manipulating
#
# #### Controller:
#
# - "Business logic" - how to manipulate data
#
# ## **Focus of this course**
#
# - Platform:
#
#     - Web-based
#
# - Architecture:
#
#     - Client-server
#
# - Software architecture:
#
#     - Model-View-Controller

# %% [markdown]
# # ***By ChatGPT***
#
# ## 🏗️ What is Software Architecture?
# - Software architecture is the structure of a software system. It defines how different parts of a system interact, how data flows, and how the application is organized.
#
# ## 🔄 Model-View-Controller (MVC) Architecture
# - ✅ Purpose:
#     - Separates concerns in application development.
#     - Improves maintainability, testability, and scalability.
#
# ## 🔹 Components of MVC:
# ### 1. Model
#    - Represents the data and manipulation.
#
#    - Notifies the view when data changes.
#
#    - Example: A database of users or products.
#
# ### 2. View
#    - Responsible for the user interface (UI).
#
#    - Displays data from the model.
#
#    - Example: HTML pages, buttons, charts.
#
# ### 3. Controller
#    - Acts as a bridge between the View and the Model and business logic..
#
#    - Handles user input, processes it, and updates the model or view.
#
#    - Example: When a user clicks “submit,” the controller takes action.
#
# ## 🔁 MVC Flow Example:
# - User clicks "Login" → Controller → Validates data via Model → Updates View
#
# ## 🎯 Benefits of MVC:
#
# | Feature             | Benefit                        |
# | ------------------- | ------------------------------ |
# | Separation of Logic | Easier to manage code          |
# | Reusability         | Components can be reused       |
# | Maintainability     | Easier to update one part only |
#
# ## 🧠 Example (Login Page)
#
# | Component  | Role                                |
# | ---------- | ----------------------------------- |
# | Model      | Stores user credentials             |
# | View       | Displays login form                 |
# | Controller | Validates login and calls the model  and business logic. |
#
# # ***✅ Summary***
#
# - Software architecture defines structure and interaction of application parts.
#
# - MVC is a powerful pattern that separates data, UI, and logic.
#
# - It is especially popular in web and mobile development (e.g., Django, Ruby on Rails, React-MVC patterns).
