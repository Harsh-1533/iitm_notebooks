# %% [markdown]
# ### 🔷 **Topological Sorting – Explained**
#
# **Topological Sorting** is a linear ordering of the **vertices** of a **Directed Acyclic Graph (DAG)** such that for every **directed edge** $u \rightarrow v$, vertex $u$ comes **before** vertex $v$ in the ordering.
#
# ---
#
# ### 🔑 **When Is Topological Sorting Possible?**
#
# Topological sorting is only possible **if and only if** the graph is a **DAG** (Directed Acyclic Graph).
# If the graph contains a **cycle**, topological sort **does not exist**.
#
# ---
#
# ### 🔹 **Example**
#
# Consider this DAG:
#
# ```
# A → C
# B → C
# C → D
# ```
#
# Possible topological orders:
#
# * A, B, C, D
# * B, A, C, D
#
# Each respects the direction of dependencies.
#
# ---
#
# ### 🔧 **Topological Sort Algorithms**
#
# #### ✅ **1. Kahn’s Algorithm (Using In-Degree and Queue)**
#
# * Count **in-degrees** of all vertices.
# * Start with nodes of **in-degree 0**.
# * Remove them and decrease in-degrees of neighbors.
# * Repeat.
#
# **Time Complexity:** $O(V + E)$
#
# #### ✅ **2. DFS-Based Algorithm**
#
# * Perform DFS on unvisited nodes.
# * **Post-order**: When a node finishes, **push it onto a stack**.
# * At the end, the stack gives the **topological order**.
#
# **Time Complexity:** $O(V + E)$
#
# ---
#
# ### 📘 **Applications of Topological Sort**
#
# * **Task Scheduling** (e.g., build systems)
# * **Course prerequisite checking**
# * **Dependency resolution** (e.g., npm, pip)
# * **Instruction ordering** in compilers
# * **Data processing pipelines**
#
# ---
#
# ### 🧠 **Key Properties**
#
# * A DAG can have **more than one** valid topological order.
# * If there's **any cycle**, topological sort **is not possible**.
#
# ---
#
# ### ✅ Summary Table
#
# | Feature         | Topological Sort                        |
# | --------------- | --------------------------------------- |
# | Graph Type      | Directed Acyclic Graph (DAG)            |
# | Output          | Linear order of vertices                |
# | Main Algorithms | DFS-based, Kahn’s algorithm             |
# | Time Complexity | $O(V + E)$                              |
# | Applications    | Scheduling, dependency resolution, etc. |
#
# ---
