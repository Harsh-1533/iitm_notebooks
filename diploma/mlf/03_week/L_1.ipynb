# %% [markdown]
# # **Title: Understanding the Four Fundamental Subspaces of a Matrix (with Examples)**
#
# ---
#
# ## 📘 Introduction
#
# In linear algebra, every matrix gives rise to **four fundamental subspaces** that help us understand its structure:
#
# 1. **Column Space (C(A))**
# 2. **Null Space (N(A))**
# 3. **Row Space (C(Aᵗ))**
# 4. **Left Null Space (N(Aᵗ))**
#
# These spaces relate to each other through the **Rank-Nullity Theorem** and reveal important geometric and algebraic properties of the matrix.
#
# ---
#
# ## ✉️ Given Matrix Example
#
# Let:
#
# ```markdown
# A =
# [  1   3   3   2
#    2   6   9   7
#   -1  -3   3   4 ]
# ```
#
# This is a 3x4 matrix.
#
# ---
#
# ## 📊 Step 1: Row Reduce A
#
# We perform Gaussian elimination to bring A into row echelon form (REF):
#
# After row operations, we get:
#
# ```markdown
# REF of A =
# [ 1   3   3   2
#   0   0   3   3
#   0   0   0   0 ]
# ```
#
# * **Pivot Columns**: Column 1, Column 3
# * **Rank(A) = 2**
#
# ---
#
# ## 1. Column Space C(A)
#
# The column space of A is the span of the **pivot columns** of the original matrix A:
#
# ```markdown
# C(A) = span{ [1 2 -1]ᵗ, [3 9 3]ᵗ }
# ```
#
# It is a **2D subspace of** ℝ³.
#
# **🔁 Remark:**
#
# > The column space **C(A)** is **orthogonal** to the **left null space** **N(Aᵗ)**.
#
# ---
#
# ## 2. Null Space N(A)
#
# Solve A·x = 0. From REF, the system becomes:
#
# ```markdown
# x₁ + 3x₂ + 3x₃ + 2x₄ = 0
# 3x₃ + 3x₄ = 0  →  x₃ = -x₄
# ```
#
# Substitute:
#
# ```markdown
# x₁ = -3x₂ + x₄
# ```
#
# Let:
#
# * x₂ = s (free variable)
# * x₄ = t (free variable)
#
# Then general solution:
#
# ```markdown
# x = s * [-3 1 0 0]ᵗ + t * [1 0 -1 1]ᵗ
# ```
#
# ```markdown
# N(A) = span{ [-3 1 0 0]ᵗ, [1 0 -1 1]ᵗ }
# ```
#
# This is a **2D subspace of** ℝ⁴.
#
# ---
#
# ## 3. Row Space C(Aᵗ)
#
# The row space is the span of the **nonzero rows** of REF of A:
#
# ```markdown
# C(Aᵗ) = span{ [1 3 3 2], [0 0 1 1] }
# ```
#
# This is a **2D subspace of** ℝ⁴.
#
# **🔁 Remark:**
#
# > The row space **C(Aᵗ)** is **orthogonal** to the **null space** **N(A)**.
#
# ---
#
# ## 4. Left Null Space N(Aᵗ)
#
# This is the set of all vectors y such that:
#
# ```markdown
# Aᵗ·y = 0
# ```
#
# Since A is 3x4, Aᵗ is 4x3. Use rank-nullity:
#
# * Rank of Aᵗ = Rank of A = 2
# * Nullity(Aᵗ) = 3 - 2 = 1
#
# So the left null space is a **1D subspace of** ℝ³.
#
# ---
#
# ## 🔍 Summary Table
#
# | Subspace        | Description                   | Dimension | Example Basis Vectors     |
# | --------------- | ----------------------------- | --------- | ------------------------- |
# | Column Space    | Span of pivot columns         | 2 (in ℝ³) | \[1,2,-1], \[3,9,3]       |
# | Null Space      | Solutions to A·x = 0          | 2 (in ℝ⁴) | \[-3,1,0,0], \[1,0,-1,1]  |
# | Row Space       | Span of non-zero rows (A REF) | 2 (in ℝ⁴) | \[1,3,3,2], \[0,0,1,1]    |
# | Left Null Space | Solutions to Aᵗ·y = 0         | 1 (in ℝ³) | Found by solving Aᵗ·y = 0 |
#
# ---

# %% [markdown]
# # Also prefer My Campus Notebook
