# %% [markdown]
# # ✅ Topic: Continuity and Differentiability of a Function (Univariate Calculus)
#
# ---
#
# ## 🔹 1. What is a Function?
#
# A **function** is like a machine that takes an input (say, $x$) and gives an output (say, $f(x)$).
#
# **Example:**
#
# $$
# f(x) = x^2
# $$
#
# If you put $x = 2$, you get:
#
# $$
# f(2) = 2^2 = 4
# $$
#
# ---
#
# ## 🔹 2. What is Continuity?
#
# 🎯 Think of continuity like **drawing a graph without lifting your pen**.
#
# A function is **continuous at a point** $x = a$ if:
#
# 1. $f(a)$ is defined
# 2. $\lim_{x \to a} f(x)$ exists
# 3. $\lim_{x \to a} f(x) = f(a)$
#
# ---
#
# ### 🔍 Simple Example:
# Let’s look at this function:
#
# $$
# f(x) = x^2
# $$
#
# Check at $x = 2$:
#
# - $f(2) = 4$ ✅
# - $\lim_{x \to 2} f(x) = 4$ ✅
# - So, $\lim_{x \to 2} f(x) = f(2)$ ⇒ **Continuous** ✅
#
# ✔️ No jumps, no holes, just a smooth curve.
#
# ---
#
# ### ❌ Discontinuous Example:
#
# $$
# f(x) = \begin{cases}
# 1 & \text{if } x < 0 \\
# 2 & \text{if } x \geq 0
# \end{cases}
# $$
#
# At $x = 0$:
#
# - From left: $\lim_{x \to 0^-} f(x) = 1$
# - From right: $\lim_{x \to 0^+} f(x) = 2$
#
# Since left and right limits are **not equal**, the function is **not continuous** at $x = 0$.
#
# ---
#
# ## 🔹 3. What is Differentiability?
#
# 🎯 Differentiability means:
#
# > Can I draw a smooth tangent (slope) at that point?
#
# If the function has a **sharp corner**, it's **not differentiable** at that point.
#
# ---
#
# ### 🔍 Easy Example:
#
# $$
# f(x) = x^2
# $$
#
# It’s a smooth curve, so it's differentiable everywhere.
#
# The derivative is:
#
# $$
# f'(x) = 2x
# $$
#
# At $x = 2$:
#
# $$
# f'(2) = 2 \cdot 2 = 4
# $$
#
# ✅ Differentiable at $x = 2$
#
# ---
#
# ### ❌ Not Differentiable Example:
#
# $$
# f(x) = |x| = \begin{cases}
# -x & \text{if } x < 0 \\
# x & \text{if } x \geq 0
# \end{cases}
# $$
#
# At $x = 0$, the graph makes a **sharp V-shape**.
#
# Let’s find the slope from both sides:
#
# - Left derivative:
#
# $$
# \lim_{h \to 0^-} \frac{f(0 + h) - f(0)}{h} = \lim_{h \to 0^-} \frac{-h - 0}{h} = -1
# $$
#
# - Right derivative:
#
# $$
# \lim_{h \to 0^+} \frac{f(0 + h) - f(0)}{h} = \lim_{h \to 0^+} \frac{h - 0}{h} = 1
# $$
#
# Since left and right derivatives are **not equal**, the function is **not differentiable** at $x = 0$.
#
# ---
#
# ## 🔁 Key Idea:
#
# | Concept            | Easy Meaning                         | Visual Clue     |
# |--------------------|--------------------------------------|------------------|
# | **Continuous**      | No jump or hole in the graph         | Smooth drawing   |
# | **Differentiable**  | No sharp corner; smooth slope        | No "V" or cusp   |
#
# ---
#
# ## 🧠 Final Summary:
#
# - If you can draw the graph **without lifting your pen**, it's **continuous**.
# - If you can also draw it **without hitting a sharp corner**, it's **differentiable**.
# - A differentiable function is **always continuous**.
# - But a continuous function **may not** be differentiable (like $f(x) = |x|$).
#
# ---
